# %%
import datetime
import pandas as pd
import yfinance as y
import matplotlib.pyplot as plt
import numpy as np

# %%
start = datetime.datetime(2020, 1, 1)
end = datetime.datetime(2021, 1, 1)

# %%
papeis = ['petr4.sa', 'vale3.sa', 'itub4.sa', 'bpac11.sa']

# %%
ibov = y.download('^bvsp', start, end)['Adj Close']
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
ibov
# Out:
# Date
# 2020-01-02    118573.0
# 2020-01-03    117707.0
# 2020-01-06    116878.0
# 2020-01-07    116662.0
# 2020-01-08    116247.0
#                 ...
# 2020-12-22    116348.0
# 2020-12-23    117857.0
# 2020-12-28    119051.0
# 2020-12-29    119475.0
# 2020-12-30    119306.0
# Name: Adj Close, Length: 248, dtype: float64

# %%
carteira = y.download(papeis, start, end)['Adj Close']
# Out:
# [*********************100%***********************]  4 of 4 completed

# %%
carteira
# Out:
#             BPAC11.SA   ITUB4.SA   PETR4.SA   VALE3.SA
# Date
# 2020-01-02  18.235773  35.783096  24.950865  44.330601
# 2020-01-03  18.288692  35.406731  24.747683  44.004223
# 2020-01-06  18.262236  34.879818  25.040264  43.743118
# 2020-01-07  18.335096  34.070629  24.942738  44.061337
# 2020-01-08  18.172602  33.515480  24.788317  44.069500
# ...               ...        ...        ...        ...
# 2020-12-22  22.688028  30.149210  22.172966  73.904175
# 2020-12-23  22.722210  30.814901  22.717539  74.261200
# 2020-12-28  23.247110  31.036798  22.904478  74.218697
# 2020-12-29  23.300821  30.969263  22.977631  74.014687
# 2020-12-30  22.927286  30.515829  23.034527  74.337700
#
# [248 rows x 4 columns]

# %%
(carteira / carteira.iloc[0]).plot(figsize=(13,8))
(ibov / ibov.iloc[0]).plot(label = 'IBOV').legend()

# %%
rentabilidade = carteira.pct_change() * 100
rentabilidade_anual = np.sum(rentabilidade) # rentabilidade.mean() * 250

# %%
rentabilidade_anual
# Out:
# BPAC11.SA    53.160277
# ITUB4.SA     -4.575187
# PETR4.SA     16.178425
# VALE3.SA     66.515908
# dtype: float64

# %%
rentabilidade_ibov = ibov.pct_change() * 100
rentabilidade_ibov_anual = np.sum(rentabilidade_ibov) # rentabilidade.mean() * 250

# %%
rentabilidade_ibov_anual
# Out:
# 10.591287255955677

# %%
peso = np.array([0.25, 0.25, 0.25, 0.25])

# %%
rentabilidade_carteira = np.dot(rentabilidade_anual, peso)

# %%
rentabilidade_carteira
# Out:
# 32.81985596015129

# %%
rentabilidade.plot()
# Out:
# <AxesSubplot:xlabel='Date'>
