# %%
import numpy as np
import pandas as pd
import yfinance as yf
import datetime
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import ParameterGrid

# %% [markdown]
# ## Download dos dados

# %%
start_date = datetime.datetime(2018, 1, 1)
end_date = datetime.datetime(2021, 1, 1)
stock = 'AAPL'

# %%
ticker = yf.download(stock, start_date, end_date)
data = pd.DataFrame(ticker)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
def fetch_data(symbol, start, end):
    data = {}
    ticker = yf.download(symbol, start, end)
    return pd.DataFrame(ticker)

def construct_signals(data, ma_period=60, period=14, lags=2):
    data['SMA'] = data['Close'].rolling(window=ma_period).mean()
    
    # trend
    data['trend'] = (data['Open'] - data['SMA']) * 100
    
    # Relative Strength Indicator
    data['move'] = data['Close'] - data['Close'].shift(1)
    data['up'] = np.where(data['move'] > 0, data['move'], 0)
    data['down'] = np.where(data['move'] < 0, data['move'], 0)
    data['average_gain'] = data['up'].rolling(period).mean()
    data['average_loss'] = data['down'].abs().rolling(period).mean()
    data['relative_strength'] = data['average_gain'] / data['average_loss']
    rsi = 100.0 - (100.0 / (1.0 + data['relative_strength']))
    data['RSI'] = rsi / 100 # features with same order

    # Average True Range
    high_low = data['High'] - data['Low']
    high_close = np.abs(data['High'] - data['Close'].shift())
    low_close = np.abs(data['Low'] - data['Close'].shift())
    
    ranges = pd.concat([high_low, high_close, low_close], axis=1)
    true_ranges = np.max(ranges, axis=1)
    
    data['ATR'] = true_ranges.rolling(14).mean() # true_ranges.rolling(14).sum() / 14
    
    # Boillinger Bands
    data['tp'] = (data['Close'] + data['Low'] + data['High']) / 3
    data['std'] = data['tp'].rolling(20).std()
    data['ma'] = data['tp'].rolling(20).mean()
    data['upper_band'] = data['ma'] + 2 * data['std']
    data['lower_band'] = data['ma'] - 2 * data['std']
    
    data['boillinger'] = np.where(data['Close']  > data['upper_band'], 1, -1)
    
    # Crossover Strategy
    data['short_ma'] = data['Close'].ewm(span=30).mean()
    data['long_ma'] = data['Close'].ewm(span=50).mean()
    data['crossover'] = np.where(data['short_ma']  > data['long_ma'], 1, -1)
    
    # we need the targed variables (labels)
    data['direction'] = np.where(data['Close'] - data['Open'] > 0, 1, -1)

# %%
start_date = datetime.datetime(2018, 1, 1)
end_date = datetime.datetime(2021, 1, 1)

# EUR-USD currency pair
currency_data = fetch_data('^GSPC', start_date, end_date) # ABEV3.SA
construct_signals(currency_data)
currency_data = currency_data.dropna()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
currency_data
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2018-03-28  2611.300049  2632.649902  2593.060059  2605.000000  2605.000000
# 2018-03-29  2614.409912  2659.070068  2609.719971  2640.870117  2640.870117
# 2018-04-02  2633.449951  2638.300049  2553.800049  2581.879883  2581.879883
# 2018-04-03  2592.169922  2619.139893  2575.489990  2614.449951  2614.449951
# 2018-04-04  2584.040039  2649.860107  2573.610107  2644.689941  2644.689941
# ...                 ...          ...          ...          ...          ...
# 2020-12-24  3694.030029  3703.820068  3689.320068  3703.060059  3703.060059
# 2020-12-28  3723.030029  3740.510010  3723.030029  3735.360107  3735.360107
# 2020-12-29  3750.010010  3756.120117  3723.310059  3727.040039  3727.040039
# 2020-12-30  3736.189941  3744.629883  3730.209961  3732.040039  3732.040039
# 2020-12-31  3733.270020  3760.199951  3726.879883  3756.070068  3756.070068
#
#                 Volume          SMA         trend       move         up  ...  \
# Date                                                                     ...
# 2018-03-28  3864500000  2735.020166 -12372.011719  -7.620117   0.000000  ...
# 2018-03-29  3565990000  2734.104500 -11969.458822  35.870117  35.870117  ...
# 2018-04-02  3598520000  2731.918164  -9846.821289 -58.990234   0.000000  ...
# 2018-04-03  3392810000  2730.092497 -13792.257487  32.570068  32.570068  ...
# 2018-04-04  3350340000  2728.451497 -14441.145833  30.239990  30.239990  ...
# ...                ...          ...           ...        ...        ...  ...
# 2020-12-24  1885090000  3542.292660  15173.736979  13.050049  13.050049  ...
# 2020-12-28  3527460000  3548.201994  17482.803548  32.300049  32.300049  ...
# 2020-12-29  3387030000  3554.512329  19549.768066  -8.320068   0.000000  ...
# 2020-12-30  3145200000  3559.902995  17628.694661   5.000000   5.000000  ...
# 2020-12-31  3172510000  3566.487996  16678.202311  24.030029  24.030029  ...
#
#                      tp        std           ma   upper_band   lower_band  \
# Date
# 2018-03-28  2610.236654  54.495393  2707.777169  2816.767954  2598.786383
# 2018-03-29  2636.553385  56.671156  2705.134676  2818.476989  2591.792363
# 2018-04-02  2591.326660  61.931000  2700.787341  2824.649342  2576.925341
# 2018-04-03  2603.026611  65.622983  2695.525671  2826.771638  2564.279705
# 2018-04-04  2622.720052  67.203606  2690.470671  2824.877882  2556.063459
# ...                 ...        ...          ...          ...          ...
# 2020-12-24  3698.733398  24.685808  3677.872168  3727.243785  3628.500551
# 2020-12-28  3732.966715  25.662612  3682.654000  3733.979224  3631.328776
# 2020-12-29  3735.490072  23.230841  3688.591842  3735.053524  3642.130160
# 2020-12-30  3735.626628  24.605669  3692.260339  3741.471677  3643.049001
# 2020-12-31  3747.716634  26.425780  3696.566003  3749.417563  3643.714444
#
#             boillinger     short_ma      long_ma  crossover  direction
# Date
# 2018-03-28          -1  2701.594956  2713.862931         -1         -1
# 2018-03-29          -1  2697.609030  2710.727248         -1          1
# 2018-04-02          -1  2690.021192  2705.212762         -1         -1
# 2018-04-03          -1  2685.071520  2701.342109         -1          1
# 2018-04-04          -1  2682.429249  2698.934391         -1          1
# ...                ...          ...          ...        ...        ...
# 2020-12-24          -1  3639.784295  3586.348433          1          1
# 2020-12-28           1  3645.950477  3592.192028          1          1
# 2020-12-29          -1  3651.182062  3597.480185          1         -1
# 2020-12-30          -1  3656.398705  3602.757042          1         -1
# 2020-12-31           1  3662.829116  3608.769318          1          1
#
# [697 rows x 26 columns]

# %%
X = currency_data[['trend', 'RSI', 'ATR', 'boillinger', 'crossover']]
y = currency_data['direction']

# %%
# split the data into training and test set (80% - 20%)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
# possible values for the parameters
parameters = {'gamma': [10, 1, 0.1, 0.01, 0.001],
             'C': [1, 10, 100, 1000, 10000]}
grid = list(ParameterGrid(parameters))

best_accuracy = 0
best_parameter = None

for p in grid:
    model = SVC(C=p['C'], gamma=p['gamma'])
    model.fit(X_train, y_train)
    predictions = model.predict(X_test)
    accuracy = accuracy_score(y_test, predictions)
    print('Accuracy of the model: %.4f' % accuracy)
    
    if accuracy > best_accuracy:
        best_accuracy = accuracy
        best_parameter = p

print('We have found the best parameters...')
print(best_accuracy)
print(best_parameter)
# Out:
# Accuracy of the model: 0.5429
# Accuracy of the model: 0.5429
# Accuracy of the model: 0.5381
# Accuracy of the model: 0.5333
# Accuracy of the model: 0.5048
# Accuracy of the model: 0.5429
# Accuracy of the model: 0.5429
# Accuracy of the model: 0.5429
# Accuracy of the model: 0.5333
# Accuracy of the model: 0.5000
# Accuracy of the model: 0.5429
# Accuracy of the model: 0.5429
# Accuracy of the model: 0.5429
# Accuracy of the model: 0.5381
# Accuracy of the model: 0.5095
# Accuracy of the model: 0.5429
# Accuracy of the model: 0.5429
# Accuracy of the model: 0.5429
# Accuracy of the model: 0.5429
# Accuracy of the model: 0.5095
# Accuracy of the model: 0.5429
# Accuracy of the model: 0.5429
# Accuracy of the model: 0.5429
# Accuracy of the model: 0.5429
# Accuracy of the model: 0.5238
# We have found the best parameters...
# 0.5428571428571428
# {'C': 1, 'gamma': 10}

# %%
model = SVC(C=best_parameter['C'], gamma=best_parameter['gamma'])
model.fit(X_train, y_train)
predictions = model.predict(X_test)
print('Accuracy of the model: %.2f' % accuracy_score(y_test, predictions))
print(confusion_matrix(predictions, y_test))
# Out:
# Accuracy of the model: 0.54
# [[  0   0]
#  [ 96 114]]

# %%
y.value_counts()
# Out:
#  1    386
# -1    311
# Name: direction, dtype: int64

# %%
currency_data['trend'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier()

# %%
model.fit(X_train, y_train)
predictions = model.predict(X_test)
accuracy = accuracy_score(y_test, predictions)
print(accuracy)
# Out:
# 0.580952380952381

# %%
accuracy
# Out:
# 0.580952380952381
