# %%
import datetime
import pandas as pd
import yfinance as y
import matplotlib.pyplot as plt
import numpy as np

# %%
start = datetime.datetime(2021, 1, 1)
end = datetime.datetime(2022, 1, 1)

# %%
papeis = ['petr4.sa', 'vale3.sa', 'itub4.sa', 'bpac11.sa']

# %%
ibov = y.download('^bvsp', start, end)['Adj Close']
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
ibov
# Out:
# Date
# 2021-01-04    118558.0
# 2021-01-05    119223.0
# 2021-01-06    119851.0
# 2021-01-07    121956.0
# 2021-01-08    125077.0
#                 ...
# 2021-12-23    104891.0
# 2021-12-27    105531.0
# 2021-12-28    104864.0
# 2021-12-29    104107.0
# 2021-12-30    104822.0
# Name: Adj Close, Length: 247, dtype: float64

# %%
carteira = y.download(papeis, start, end)['Adj Close']
# Out:
# [*********************100%***********************]  4 of 4 completed

# %%
carteira
# Out:
#             BPAC11.SA   ITUB4.SA   PETR4.SA   VALE3.SA
# Date
# 2021-01-04  22.724649  29.825676  23.497816  77.746445
# 2021-01-05  22.553747  29.632637  24.416275  79.055534
# 2021-01-06  21.826210  30.501341  24.465040  81.648216
# 2021-01-07  21.964533  31.688576  25.196552  86.978088
# 2021-01-08  22.660295  31.678917  25.294088  86.706070
# ...               ...        ...        ...        ...
# 2021-12-23  21.291933  21.322021  28.330000  79.150002
# 2021-12-27  21.311777  21.541836  28.750000  78.949997
# 2021-12-28  20.557730  21.461903  28.780001  77.050003
# 2021-12-29  20.567652  21.282053  28.540001  77.250000
# 2021-12-30  20.805771  20.932350  28.450001  77.959999
#
# [247 rows x 4 columns]

# %%
(carteira / carteira.iloc[0]).plot(figsize=(13,8))
(ibov / ibov.iloc[0]).plot(label = 'IBOV').legend()

# %%
rentabilidade = carteira.pct_change() * 100
rentabilidade_anual = np.sum(rentabilidade) # rentabilidade.mean() * 250

# %%
rentabilidade_anual
# Out:
# BPAC11.SA    -1.050032
# ITUB4.SA    -29.155812
# PETR4.SA     28.783316
# VALE3.SA      6.281142
# dtype: float64

# %%
rentabilidade_ibov = ibov.pct_change() * 100
rentabilidade_ibov_anual = np.sum(rentabilidade_ibov) # rentabilidade.mean() * 250

# %%
rentabilidade_ibov_anual
# Out:
# -10.155971273589422

# %%
peso = np.array([0.25, 0.25, 0.25, 0.25])

# %%
rentabilidade_carteira = np.dot(rentabilidade_anual, peso)

# %%
rentabilidade_carteira
# Out:
# 1.214653623748787

# %%
rentabilidade.plot()
# Out:
# <AxesSubplot:xlabel='Date'>
