# %%
import numpy as np
import yfinance as yf
from scipy.stats import norm
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import keras
# Out:
# 2022-03-10 15:10:41.752562: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH:
# 2022-03-10 15:10:41.752586: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
start_date = datetime.datetime(2012, 1, 12)
end_date = datetime.datetime(2020, 8, 12)
stocks = ['AAPL', 'BA', 'T', 'MGM', 'AMZN', 'IBM', 'TSLA', 'GOOG', '^GSPC']

# %% [markdown]
# ## Download dos dados

# %%
data = {}

for stock in stocks:
    ticker = yf.download(stock, start_date, end_date)
    data[stock] = ticker['Close']
stock_price_df = pd.DataFrame(data)

#stock_price_df = stock_price_df.rename(columns={'^GSPC': 'sp500'})
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
stock_price_df
# Out:
#                   AAPL          BA          T        MGM         AMZN  \
# Date
# 2012-01-12   15.049643   75.510002  30.120001  12.130000   175.929993
# 2012-01-13   14.993214   74.599998  30.070000  12.350000   178.419998
# 2012-01-17   15.167857   75.239998  30.250000  12.250000   181.660004
# 2012-01-18   15.325357   75.059998  30.330000  12.730000   189.440002
# 2012-01-19   15.276786   75.559998  30.420000  12.800000   194.449997
# ...                ...         ...        ...        ...          ...
# 2020-08-05  110.062500  174.279999  29.850000  16.719999  3205.030029
# 2020-08-06  113.902496  172.199997  29.840000  18.459999  3225.000000
# 2020-08-07  111.112503  170.020004  30.020000  19.030001  3167.459961
# 2020-08-10  112.727501  179.410004  30.200001  21.650000  3148.159912
# 2020-08-11  109.375000  180.130005  30.200001  21.500000  3080.669922
#
#                    IBM        TSLA         GOOG        ^GSPC
# Date
# ...

# %%
data = {}

for stock in stocks:
    ticker = yf.download(stock, start_date, end_date)
    data[stock] = ticker['Volume']
stock_vol_df = pd.DataFrame(data)

# stock_price_vol = stock_price_vol.rename(columns={'^GSPC': 'sp500'})
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
stock_vol_df
# Out:
#                  AAPL        BA         T       MGM     AMZN      IBM  \
# Date
# 2012-01-12  212587200   3934500  26511100  17891100  5385800  7197526
# 2012-01-13  226021600   4641100  22096800  16621800  4753500  5522043
# 2012-01-17  242897200   3700100  23500200  15480800  5644500  6279556
# 2012-01-18  276791200   4189500  22015000  18387600  7473500  4812228
# 2012-01-19  261738400   5397300  25524000  14022900  7096000  8961291
# ...               ...       ...       ...       ...      ...      ...
# 2020-08-05  121776800  46189200  22951300  18857900  3916500  3786102
# 2020-08-06  202428800  32921600  21908700  35867700  3940600  3574287
# 2020-08-07  198045600  19318000  30422100  34572100  3936100  3818946
# 2020-08-10  212403600  35857700  35514400  71219700  3167300  4150842
# 2020-08-11  187902400  61036600  30986900  34396000  3718100  5231255
#
#                 TSLA      GOOG       ^GSPC
# Date
# 2012-01-12   3646500   3764457  4019890000
# ...

# %%
stock_price_df.isnull().sum()
# Out:
# AAPL     0
# BA       0
# T        0
# MGM      0
# AMZN     0
# IBM      0
# TSLA     0
# GOOG     0
# ^GSPC    0
# dtype: int64

# %%
stock_price_df.describe()
# Out:
#               AAPL           BA            T          MGM         AMZN  \
# count  2159.000000  2159.000000  2159.000000  2159.000000  2159.000000
# mean     35.204956   189.942700    35.162899    23.105743   915.665665
# std      17.706900   103.678586     3.207490     6.963847   697.838905
# min      13.947500    67.239998    26.770000     7.140000   175.929993
# 25%      22.291429   124.014999    33.040001    18.545000   316.490005
# 50%      29.150000   142.419998    34.930000    23.780001   676.010010
# 75%      43.754999   297.044998    37.419998    28.430000  1593.645020
# max     113.902496   440.619995    43.470001    38.029999  3225.000000
#
#                IBM         TSLA         GOOG        ^GSPC
# count  2159.000000  2159.000000  2159.000000  2159.000000
# mean    154.734984    51.920163   783.712512  2218.749554
# std      24.438017    42.197600   334.448057   537.321727
# min      90.602295     4.558000   278.481171  1278.040039
# ...

# %%
ticker = yf.download('AAPL', start_date, end_date)
ticker
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2012-01-12   15.081429   15.103571   14.955357   15.049643   12.886623
# 2012-01-13   14.989286   15.016071   14.952143   14.993214   12.838301
# 2012-01-17   15.150000   15.213929   15.105714   15.167857   12.987842
# 2012-01-18   15.248571   15.338214   15.225000   15.325357   13.122705
# 2012-01-19   15.362500   15.406071   15.232500   15.276786   13.081116
# ...                ...         ...         ...         ...         ...
# 2020-08-05  109.377502  110.392502  108.897499  110.062500  108.864517
# 2020-08-06  110.404999  114.412498  109.797501  113.902496  112.662712
# 2020-08-07  113.205002  113.675003  110.292503  111.112503  110.101242
# 2020-08-10  112.599998  113.775002  110.000000  112.727501  111.701546
# 2020-08-11  111.970001  112.482498  109.107498  109.375000  108.379555
#
#                Volume
# Date
# ...

# %% [markdown]
# ## Normalize data

# %%
norm_price = {}
for stock in stocks:
    norm_price[stock] = stock_price_df[stock] / stock_price_df[stock][0]

norm_price = pd.DataFrame(norm_price)

# %%
norm_vol = {}
for stock in stocks:
    norm_vol[stock] = stock_vol_df[stock] / stock_vol_df[stock][0]

norm_vol = pd.DataFrame(norm_vol)

# %%
stock_price_df.plot(figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
stock_vol_df.plot(figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
norm_price.plot(figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
norm_vol.plot(figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
stock_price_df = stock_price_df.rename(columns={'^GSPC': 'sp500'})
stock_vol_df = stock_vol_df.rename(columns={'^GSPC': 'sp500'})

# %% [markdown]
# ## Concatenate date, stock price and volume in one dataframe

# %%
def individual_stock(price_df, vol_df, name):
    return pd.DataFrame({'Close':price_df[name], 'Volume':vol_df[name]}) # 'Date':price_df.index,

# %%
# Function to return the input/output (Target) data for AI/ML Model
# Note that our goal is to predict the future stock price
# Target stock price today will be tomorrow's price

def trading_window(data):
    n = 1 # day
    data['Target'] = data[['Close']].shift(-n) # tomorrow's stock price
    return data

# %%
price_volume_df = individual_stock(stock_price_df, stock_vol_df, 'sp500')
price_volume_df
# Out:
#                   Close      Volume
# Date
# 2012-01-12  1295.500000  4019890000
# 2012-01-13  1289.089966  3692370000
# 2012-01-17  1293.670044  4010490000
# 2012-01-18  1308.040039  4096160000
# 2012-01-19  1314.500000  4465890000
# ...                 ...         ...
# 2020-08-05  3327.770020  4732220000
# 2020-08-06  3349.159912  4267490000
# 2020-08-07  3351.280029  4104860000
# 2020-08-10  3360.469971  4318570000
# 2020-08-11  3333.689941  5087650000
#
# [2159 rows x 2 columns]

# %%
price_volume_target_df = trading_window(price_volume_df)
price_volume_target_df
# Out:
#                   Close      Volume       Target
# Date
# 2012-01-12  1295.500000  4019890000  1289.089966
# 2012-01-13  1289.089966  3692370000  1293.670044
# 2012-01-17  1293.670044  4010490000  1308.040039
# 2012-01-18  1308.040039  4096160000  1314.500000
# 2012-01-19  1314.500000  4465890000  1315.380005
# ...                 ...         ...          ...
# 2020-08-05  3327.770020  4732220000  3349.159912
# 2020-08-06  3349.159912  4267490000  3351.280029
# 2020-08-07  3351.280029  4104860000  3360.469971
# 2020-08-10  3360.469971  4318570000  3333.689941
# 2020-08-11  3333.689941  5087650000          NaN
#
# [2159 rows x 3 columns]

# %%
# Remove the last row as it will be a null value
price_volume_target_df = price_volume_target_df[:-1]
price_volume_target_df
# Out:
#                   Close      Volume       Target
# Date
# 2012-01-12  1295.500000  4019890000  1289.089966
# 2012-01-13  1289.089966  3692370000  1293.670044
# 2012-01-17  1293.670044  4010490000  1308.040039
# 2012-01-18  1308.040039  4096160000  1314.500000
# 2012-01-19  1314.500000  4465890000  1315.380005
# ...                 ...         ...          ...
# 2020-08-04  3306.510010  4621670000  3327.770020
# 2020-08-05  3327.770020  4732220000  3349.159912
# 2020-08-06  3349.159912  4267490000  3351.280029
# 2020-08-07  3351.280029  4104860000  3360.469971
# 2020-08-10  3360.469971  4318570000  3333.689941
#
# [2158 rows x 3 columns]

# %% [markdown]
# ## Scale the data

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range = (0,1))
price_volume_target_scaled_df = sc.fit_transform(price_volume_target_df)

# %%
price_volume_target_scaled_df
# Out:
# array([[0.00828228, 0.35544202, 0.00524163],
#        [0.00524163, 0.31342927, 0.00741423],
#        [0.00741423, 0.35423623, 0.01423076],
#        ...,
#        [0.98245348, 0.38720299, 0.98345918],
#        [0.98345918, 0.36634157, 0.9878185 ],
#        [0.9878185 , 0.3937553 , 0.97511517]])

# %% [markdown]
# ## Create Feature and Target

# %%
X = price_volume_target_scaled_df[:, :2]
y = price_volume_target_scaled_df[:, 2:]

# %%
# Spliting the data this way, since order is important in time-series
# NOte that we did not use train test split with its default setting since it shuffles the data

# %%
split = int(0.65 * len(X))

# %%
X_train = X[:split]
y_train = y[:split]

X_test = X[split:]
y_test = y[split:]

# %% [markdown]
# ## Plotting data

# %%
# Define the data plotting function

def show_plot(data, title):
    plt.figure(figsize=(13, 5))
    plt.plot(data, linewidth = 3)
    plt.title(title)
    plt.grid()

# %%
show_plot(X_train, 'Training Data')
show_plot(X_test, 'Testing Data')

# %% [markdown]
# ## Build and train a ridge linear regression model

# %%
from sklearn.linear_model import Ridge
# Note the Ridge regression performs linear least squares with L2 regularization
# Create and train the ridge linear regression model
regression_model = Ridge()
regression_model.fit(X_train, y_train)
# Out:
# Ridge()

# %%
# Test the model and calculate its accuracy
lr_accuracy = regression_model.score(X_test, y_test)
print('Ridge Regression Score: ', lr_accuracy)
# Out:
# Ridge Regression Score:  0.9513168548748439

# %%
# Make Prediction
predicted_prices = regression_model.predict(X)
predicted_prices
# Out:
# array([[0.01766673],
#        [0.01461495],
#        [0.01682302],
#        ...,
#        [0.96114394],
#        [0.96206464],
#        [0.9663562 ]])

# %%
# Append the predicted values into a list
predicted = []
for i in predicted_prices:
    predicted.append(i[0])

# %%
# Append the close values to the list
close = []
for i in price_volume_target_scaled_df:
    close.append(i[0])

# %%
# Create a dataframe based on the dates in the individual stock data
df_predicted = price_volume_target_df.index
df_predicted = pd.DataFrame(predicted, columns=['Predicted'])
df_predicted['Close'] = close
df_predicted.index = price_volume_target_df.index
df_predicted
# Out:
#             Predicted     Close
# Date
# 2012-01-12   0.017667  0.008282
# 2012-01-13   0.014615  0.005242
# 2012-01-17   0.016823  0.007414
# 2012-01-18   0.023452  0.014231
# 2012-01-19   0.026541  0.017295
# ...               ...       ...
# 2020-08-04   0.941668  0.962222
# 2020-08-05   0.951470  0.972307
# 2020-08-06   0.961144  0.982453
# 2020-08-07   0.962065  0.983459
# 2020-08-10   0.966356  0.987819
#
# [2158 rows x 2 columns]

# %%
# Plot the results
df_predicted.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## LSTM Time Series

# %%
# Let's test the functions and get individual stock prices and volumes for AAPL
price_volume_df = individual_stock(stock_price_df, stock_vol_df, 'sp500')
price_volume_df
# Out:
#                   Close      Volume
# Date
# 2012-01-12  1295.500000  4019890000
# 2012-01-13  1289.089966  3692370000
# 2012-01-17  1293.670044  4010490000
# 2012-01-18  1308.040039  4096160000
# 2012-01-19  1314.500000  4465890000
# ...                 ...         ...
# 2020-08-05  3327.770020  4732220000
# 2020-08-06  3349.159912  4267490000
# 2020-08-07  3351.280029  4104860000
# 2020-08-10  3360.469971  4318570000
# 2020-08-11  3333.689941  5087650000
#
# [2159 rows x 2 columns]

# %%
# Get the close and volume data as training data (Input)
training_data = price_volume_df.iloc[:, 0:2].values
training_data
# Out:
# array([[1.29550000e+03, 4.01989000e+09],
#        [1.28908997e+03, 3.69237000e+09],
#        [1.29367004e+03, 4.01049000e+09],
#        ...,
#        [3.35128003e+03, 4.10486000e+09],
#        [3.36046997e+03, 4.31857000e+09],
#        [3.33368994e+03, 5.08765000e+09]])

# %%
# Normalize the data
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_data)

# %%
# Create the training and testing data, training data contains present day and previous day values
X = []
y = []
for i in range(1, len(price_volume_df)):
    X.append(training_set_scaled [i-1:i, 0]) # yesterday's price
    y.append(training_set_scaled [i, 0]) # today price

# %%
# Convert the data into array format
X = np.asarray(X)
y = np.asarray(y)

# %%
# Split the data
split = int(0.7 * len(X))
X_train = X[:split]
y_train = y[:split]
X_test = X[split:]
y_test = y[split:]

# %%
# Reshape the 1D arrays to 3D arrays to feed in the model
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
X_train.shape, X_test.shape
# Out:
# ((1510, 1, 1), (648, 1, 1))

# %%
# Create the model
inputs = keras.layers.Input(shape=(X_train.shape[1], X_train.shape[2]))
x = keras.layers.LSTM(150, return_sequences= True)(inputs)
x = keras.layers.Dropout(0.3)(x)
x = keras.layers.LSTM(150, return_sequences=True)(x)
x = keras.layers.Dropout(0.3)(x)
x = keras.layers.LSTM(150)(x)
outputs = keras.layers.Dense(1, activation='linear')(x) # output is continuous, sigmoid saturates

model = keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer='adam', loss="mse")
model.summary()
# Out:
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_6 (InputLayer)        [(None, 1, 1)]            0
#
#  lstm_15 (LSTM)              (None, 1, 150)            91200
#
#  dropout_10 (Dropout)        (None, 1, 150)            0
#
#  lstm_16 (LSTM)              (None, 1, 150)            180600
#
#  dropout_11 (Dropout)        (None, 1, 150)            0
#
#  lstm_17 (LSTM)              (None, 150)               180600
#
#  dense_5 (Dense)             (None, 1)                 151
#
# ...
# Total params: 452,551
# Trainable params: 452,551
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
history = model.fit(X_train, y_train, epochs = 20, batch_size = 32, validation_split = 0.2)
# Out:
# Epoch 1/20
# 38/38 [==============================] - 5s 33ms/step - loss: 0.0307 - val_loss: 0.0639
# Epoch 2/20
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0077 - val_loss: 0.0078
# Epoch 3/20
# 38/38 [==============================] - 0s 6ms/step - loss: 8.4105e-04 - val_loss: 0.0016
# Epoch 4/20
# 38/38 [==============================] - 0s 6ms/step - loss: 4.2309e-04 - val_loss: 3.0230e-04
# Epoch 5/20
# 38/38 [==============================] - 0s 6ms/step - loss: 3.7873e-04 - val_loss: 1.1172e-04
# Epoch 6/20
# 38/38 [==============================] - 0s 7ms/step - loss: 3.5352e-04 - val_loss: 5.0656e-05
# Epoch 7/20
# 38/38 [==============================] - 0s 7ms/step - loss: 3.1947e-04 - val_loss: 4.2474e-05
# Epoch 8/20
# 38/38 [==============================] - 0s 7ms/step - loss: 3.1183e-04 - val_loss: 1.1937e-04
# Epoch 9/20
# 38/38 [==============================] - 0s 6ms/step - loss: 2.8169e-04 - val_loss: 3.2348e-05
# Epoch 10/20
# ...

# %%
# Make prediction
predicted = model.predict(X)

# %%
## Apend the predicted values to the list
test_predicted = []

for i in predicted:
    test_predicted.append(i[0])

# %%
df_predicted = pd.DataFrame(price_volume_df['Close'][1:])

# %%
df_predicted['predictions'] = test_predicted

# %%
df_predicted
# Out:
#       predictions
# 0        0.007167
# 1        0.004104
# 2        0.006293
# 3        0.013160
# 4        0.016247
# ...           ...
# 2153     0.933707
# 2154     0.942704
# 2155     0.951732
# 2156     0.952625
# 2157     0.956495
#
# [2158 rows x 1 columns]

# %%
close =[]
for i in training_set_scaled:
    close.append(i[0])

# %%
df_predicted['Close'] = close[1:]

# %%
df_predicted
# Out:
#                Close  predictions
# Date
# 2012-01-13  0.005242     0.007167
# 2012-01-17  0.007414     0.004104
# 2012-01-18  0.014231     0.006293
# 2012-01-19  0.017295     0.013160
# 2012-01-20  0.017713     0.016247
# ...              ...          ...
# 2020-08-05  0.972307     0.933707
# 2020-08-06  0.982453     0.942704
# 2020-08-07  0.983459     0.951732
# 2020-08-10  0.987819     0.952625
# 2020-08-11  0.975115     0.956495
#
# [2158 rows x 2 columns]

# %%
df_predicted.plot()
# Out:
# <AxesSubplot:xlabel='Date'>
