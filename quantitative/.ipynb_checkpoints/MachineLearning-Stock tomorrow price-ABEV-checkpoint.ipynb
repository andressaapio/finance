# %%
import numpy as np
import yfinance as yf
from scipy.stats import norm
import pandas as pd
import datetime
import matplotlib.pyplot as plt
from sklearn import metrics

# %%
start_date = datetime.datetime(2012, 1, 12)
end_date = datetime.datetime(2020, 8, 12)
stocks = ['ITUB4.SA', 'BBDC4.SA', 'ABEV3.SA', 'MGLU3.SA']

# %% [markdown]
# ## Download dos dados

# %%
data = {}

for stock in stocks:
    ticker = yf.download(stock, start_date, end_date)
    data[stock] = ticker['Close']
stock_price_df = pd.DataFrame(data)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
stock_price_df
# Out:
#              ITUB4.SA   BBDC4.SA   ABEV3.SA   MGLU3.SA
# Date
# 2012-01-12  16.269381  13.703388  10.238914   0.292187
# 2012-01-13  16.164652  13.457607  10.252904   0.295625
# 2012-01-16  16.273933  13.561094  10.374819   0.295625
# 2012-01-17  16.273933  13.561094  10.442772   0.300937
# 2012-01-18  16.729277  13.819811  10.552696   0.300000
# ...               ...        ...        ...        ...
# 2020-08-05  25.670000  19.836363  13.180000  20.750000
# 2020-08-06  26.030001  19.972727  13.260000  21.477501
# 2020-08-07  25.480000  19.854546  13.310000  21.412500
# 2020-08-10  25.809999  20.027271  13.240000  20.482500
# 2020-08-11  25.510000  19.863636  13.410000  20.247499
#
# [2129 rows x 4 columns]

# %%
data = {}

for stock in stocks:
    ticker = yf.download(stock, start_date, end_date)
    data[stock] = ticker['Volume']
stock_vol_df = pd.DataFrame(data)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
stock_vol_df
# Out:
#             ITUB4.SA  BBDC4.SA  ABEV3.SA  MGLU3.SA
# Date
# 2012-01-12  10178276  12560431   1368946  31676800
# 2012-01-13  20665771  17128662    602916  18918400
# 2012-01-16   9103041   9959522    799552         0
# 2012-01-17         0         0   1674157  18377600
# 2012-01-18  18739967  12253146   1754213  37635200
# ...              ...       ...       ...       ...
# 2020-08-05  49930400  41290260  47510100  30304000
# 2020-08-06  29915600  45923020  35028900  44079200
# 2020-08-07  66608400  64384100  44280200  46478800
# 2020-08-10  30106100  32047180  28095600  61277600
# 2020-08-11  26227500  35397340  40751000  42669200
#
# [2129 rows x 4 columns]

# %%
stock_price_df.isnull().sum()
# Out:
# ITUB4.SA    0
# BBDC4.SA    0
# ABEV3.SA    0
# MGLU3.SA    0
# dtype: int64

# %%
stock_price_df.describe()
# Out:
#           ITUB4.SA     BBDC4.SA     ABEV3.SA     MGLU3.SA
# count  2129.000000  2129.000000  2129.000000  2129.000000
# mean     22.910091    19.514965    17.323453     2.673106
# std       7.394845     6.304853     2.580900     4.305788
# min      12.317009     9.681715    10.238914     0.030585
# 25%      16.290909    14.844159    16.206509     0.234375
# 50%      20.517906    17.549650    17.540001     0.359375
# 75%      28.566666    23.037189    18.940001     3.687500
# max      39.689999    35.827271    24.270000    21.750000

# %% [markdown]
# ## Normalização dos dados

# %%
norm_price = {}
for stock in stocks:
    norm_price[stock] = stock_price_df[stock] / stock_price_df[stock][0]

norm_price = pd.DataFrame(norm_price)

# %%
norm_vol = {}
for stock in stocks:
    norm_vol[stock] = stock_vol_df[stock] / stock_vol_df[stock][0]

norm_vol = pd.DataFrame(norm_vol)

# %%
stock_price_df.plot(figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
stock_vol_df.plot(figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
norm_price.plot(figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
norm_vol.plot(figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Concatenar os dados e criar o target (y)

# %%
# concatenando o close e o volume do ativo
def individual_stock(price_df, vol_df, name):
    return pd.DataFrame({'Close':price_df[name], 'Volume':vol_df[name]})

# %%
# função que cria a saída do modelo de ML 
# objetivo e predizer o valor do ativo no futuro 
# o valor do ativo hoje será o seu valor no futuro 

def trading_window(data):
    n = 1 # day
    data['Target'] = data[['Close']].shift(-n) # preço do ativo amanhã
    return data

# %%
price_volume_df = individual_stock(stock_price_df, stock_vol_df, 'ABEV3.SA')
price_volume_target_df = trading_window(price_volume_df)

# remover a última coluna, já que será um valor nulo
price_volume_target_df = price_volume_target_df[:-1]

price_volume_target_df
# Out:
#                 Close    Volume     Target
# Date
# 2012-01-12  10.238914   1368946  10.252904
# 2012-01-13  10.252904    602916  10.374819
# 2012-01-16  10.374819    799552  10.442772
# 2012-01-17  10.442772   1674157  10.552696
# 2012-01-18  10.552696   1754213  10.502731
# ...               ...       ...        ...
# 2020-08-04  13.400000  40601100  13.180000
# 2020-08-05  13.180000  47510100  13.260000
# 2020-08-06  13.260000  35028900  13.310000
# 2020-08-07  13.310000  44280200  13.240000
# 2020-08-10  13.240000  28095600  13.410000
#
# [2128 rows x 3 columns]

# %% [markdown]
# ## Escalonando os dados entre 0 e 1

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range = (0,1))
price_volume_target_scaled_df = sc.fit_transform(price_volume_target_df)

price_volume_target_scaled_df = pd.DataFrame(price_volume_target_scaled_df, columns = ['close', 'volume', 'target'], index = price_volume_target_df.index)

# %% [markdown]
# ## Separação em treino e teste

# %%
X = price_volume_target_scaled_df[['close','volume']]
y = price_volume_target_scaled_df[['target']]

# %%
# Pelo fato de ser tine series, precisamos usar shuffle=False para que os dados não fiquem aleatórios
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=False)

# %% [markdown]
# ## Plotando os dados

# %%
X_train.plot(figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
X_test.plot(figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Ridge linear regression model

# %%
# Ridge regression = performs linear least squares with L2 regularization
# Create and train the ridge linear regression model

from sklearn.linear_model import Ridge

regression_model = Ridge()
regression_model.fit(X_train, y_train)
# Out:
# Ridge()

# %%
# Test the model and calculate its accuracy
lr_accuracy = regression_model.score(X_test, y_test)
print('Ridge Regression Score: ', lr_accuracy)
# Out:
# Ridge Regression Score:  0.9870093648690064

# %%
reg_prediction = regression_model.predict(X_test)
metrics.r2_score(reg_prediction, y_test)
# Out:
# 0.9861483843893438

# %%
# Make Prediction
predicted_prices = regression_model.predict(X)

# %%
df_predicted = pd.DataFrame()
df_predicted['close'] = price_volume_target_scaled_df['close']
df_predicted['predicted'] = predicted_prices

# %%
# Plot the results
df_predicted.plot(figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# regressão linear
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X_train, y_train)

lm_prediction = lm.predict(X_test)
metrics.r2_score(lm_prediction, y_test)
# Out:
# 0.9875675860760399

# %%
plt.scatter(y_test, lm_prediction)

# %%
from sklearn.ensemble import RandomForestRegressor
rforest = RandomForestRegressor()
rforest.fit(X_train, y_train)

rforest_prediction = rforest.predict(X_test)
metrics.r2_score(rforest_prediction, y_test)
# Out:
# /run/user/1000/app/com.jetbrains.PyCharm-Community/ipykernel_4759/1826094637.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rforest.fit(X_train, y_train)
# 0.9524536049749869

# %%
plt.scatter(y_test, rforest_prediction)

# %%
from sklearn.svm import SVR
svr = SVR()
svr.fit(X_train, y_train)

svr_prediction = svr.predict(X_test)
# Out:
# /home/andressa/PycharmProjects/geral/venv/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
metrics.r2_score(svr_prediction, y_test)
# Out:
# -20.872037953874273
